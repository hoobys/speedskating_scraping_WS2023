# %%
import pandas as pd
# Set the max_rows option to display 100 rows
pd.set_option('display.max_rows', 100)

# %%
pd.read_csv('soup/soup_data.csv')
# Out:
#                            Name            Country             Birthdate  \
# 0               Achilles A-Tjak  Netherlands (NED)        May 1997 (MSA)
# 1               Arie van der Aa  Netherlands (NED)   February 1967 (M55)
# 2         Barend Jan van der Aa  Netherlands (NED)    October 1969 (M50)
# 3              Bente van der Aa  Netherlands (NED)        May 2008 (LC2)
# 4              Daisy van der Aa  Netherlands (NED)        May 1989 (L30)
# 5               Etta van der Aa  Netherlands (NED)    October 1942 (L80)
# 6               Henk van der Aa  Netherlands (NED)       July 1957 (M65)
# 7              Roman van der Aa  Netherlands (NED)   February 2002 (MN2)
# 8             Ronald van der Aa  Netherlands (NED)       June 1982 (M40)
# 9             Kristian Aabakken       Norway (NOR)       June 1996 (MSA)
# 10  Lilly Vielle Grande Aabogen       Norway (NOR)                Female
# 11   Oda Othelia Grande Aabogen       Norway (NOR)                Female
# ...

# %%
pd.read_csv('selenium/selenium_data.csv')
# Out:
#                            Name            Country             Birthdate  \
# 0               Achilles A-Tjak  Netherlands (NED)        May 1997 (MSA)
# 1               Arie van der Aa  Netherlands (NED)   February 1967 (M55)
# 2         Barend Jan van der Aa  Netherlands (NED)    October 1969 (M50)
# 3              Bente van der Aa  Netherlands (NED)        May 2008 (LC2)
# 4              Daisy van der Aa  Netherlands (NED)        May 1989 (L30)
# 5               Etta van der Aa  Netherlands (NED)    October 1942 (L80)
# 6               Henk van der Aa  Netherlands (NED)       July 1957 (M65)
# 7              Roman van der Aa  Netherlands (NED)   February 2002 (MN2)
# 8             Ronald van der Aa  Netherlands (NED)       June 1982 (M40)
# 9             Kristian Aabakken       Norway (NOR)       June 1996 (MSA)
# 10  Lilly Vielle Grande Aabogen       Norway (NOR)                Female
# 11   Oda Othelia Grande Aabogen       Norway (NOR)                Female
# ...

# %%
pd.read_csv('scrapy/speedskating/scrapy_data.csv')
# Out:
#                            Name            Country             Birthdate  \
# 0                Joey van Aalst  Netherlands (NED)                 (MA1)
# 1                 Marco Aalmoes  Netherlands (NED)       July 1963 (M55)
# 2                  Mark Aalmoes  Netherlands (NED)       July 1996 (MSA)
# 3              Joëlle van Aalst  Netherlands (NED)      April 2000 (LN4)
# 4                Pepijn Aalders  Netherlands (NED)      March 2007 (MB1)
# 5                Arto van Aalst  Netherlands (NED)  September 1963 (M55)
# 6          Isak Sagedal Aalholm       Norway (NOR)  September 1999 (MN4)
# 7          Cristoffel van Aalst  Netherlands (NED)                  Male
# 8             Jeffrey van Aalst  Netherlands (NED)  September 1991 (M30)
# 9                 Anouk Aalders  Netherlands (NED)   December 2008 (LC1)
# 10           Dylan van Aalderen  Netherlands (NED)   February 1999 (MSA)
# 11         Lysanne van Aalderen  Netherlands (NED)   December 1994 (LSA)
# ...
